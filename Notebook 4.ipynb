# %%
import pandas as pd
from utils import *

# %%
df_2018 = process_all("https://en.wikipedia.org/wiki/List_of_American_films_of_2018")

# %%
df_2018
# Out:
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 265             holmes & watson
# 266                        vice
# 267         on the basis of sex
# 268                   destroyer
# 269  black mirror: bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 265  Etan Cohen (director/screenplay); Will Ferrell...
# 266  Adam McKay (director/screenplay); Christian Ba...
# 267  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2019 = process_all("https://en.wikipedia.org/wiki/List_of_American_films_of_2019")
df_2019
# Out:
#            movie_title                                      Cast and crew  \
# 0          escape room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           rust creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     american hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     a dog's way home  Charles Martin Smith (director); W. Bruce Came...
# 4           the upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 237  spies in disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 238       little women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240         just mercy  Destin Daniel Cretton (director/screenplay), A...
# 241           clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres  \
# ...

# %%
df_2020 = process_all("https://en.wikipedia.org/wiki/List_of_American_films_of_2020")
df_2020
# Out:
#                movie_title                                      Cast and crew  \
# 0               the grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               underwater  William Eubank (director); Brian Duffield, Ada...
# 2              like a boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            three christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        inherit the viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 264       we can be heroes  Robert Rodriguez (director/screenplay); Priyan...
# 265      news of the world  Paul Greengrass (director/screenplay); Luke Da...
# 266     one night in miami  Regina King (director); Kemp Powers (screenpla...
# 267  promising young woman  Emerald Fennell (director/screenplay); Carey M...
# 268      pieces of a woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
prev_df = pd.read_csv("movies_2.csv")
df_from_2018 = df_2018.append(df_2019.append(df_2020, ignore_index=True), ignore_index=True)
all_df = prev_df.append(df_from_2018)
all_df
# Out:
#      color      director_name  num_critic_for_reviews  duration  \
# 0    Color      James Cameron                   723.0     178.0
# 1    Color     Gore Verbinski                   302.0     169.0
# 2    Color         Sam Mendes                   602.0     148.0
# 3    Color  Christopher Nolan                   813.0     164.0
# 4      NaN        Doug Walker                     NaN       NaN
# ..     ...                ...                     ...       ...
# 776    NaN   Robert Rodriguez                     NaN       NaN
# 777    NaN    Paul Greengrass                     NaN       NaN
# 778    NaN        Regina King                     NaN       NaN
# 779    NaN    Emerald Fennell                     NaN       NaN
# 780    NaN   Kornél Mundruczó                     NaN       NaN
#
#      director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                        0.0                   855.0  Joel David Moore
# ...

# %%
all_df.to_csv('all_movies.csv',index=False)
